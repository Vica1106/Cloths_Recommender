# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
rent_csv_file = './data/renttherunway_final_data.csv' 
# mete_csv_file = 'modcloth_final_data.csv' 

rent_data = pd.read_csv(rent_csv_file)
# mete_data = pd.read_csv(mete_csv_file)

# %%
def height_to_cm(height):
    if not isinstance(height, str): 
        return None 
    match = re.match(r"(\d+)' (\d+)\"", height)
    if match:
        feet = int(match.group(1)) 
        inches = int(match.group(2)) 
        return feet * 30.48 + inches * 2.54
    else:
        return None

# %% [markdown]
# convert height, weight. Using mean fill nan.

# %%
rent_data['height_cm'] = rent_data['height'].apply(height_to_cm)
rent_data['weight_kg'] = rent_data['weight'].str.replace('lbs', '').astype(float) * 0.453592

# %%
columns_to_fill = ['height_cm', 'weight_kg']  
for col in columns_to_fill:
    mean_value = rent_data[col].mean()  
    rent_data[col] = rent_data[col].fillna(mean_value)

# %%
def plot_size_distribution1(data):
    plt.figure(figsize=(10, 6))
    sns.countplot(x='size', data=data, order=sorted(data['size'].unique()))
    plt.xlabel('Clothing Size')
    plt.ylabel('Count')
    plt.title('Distribution of Clothing Size')
    
    # Calculate left 95% of the data
    upper_bound = np.percentile(data['size'], 98)
    plt.axvline(x=upper_bound, color='red', linestyle='--', label='95th Percentile')
    
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.legend()
    plt.tight_layout()
    plt.show()
    
plot_size_distribution(rent_data)

# %%
threshold = rent_data['size'].quantile(0.98)
df1 = rent_data[rent_data['size'] <= threshold]

# %%
def plot_size_distribution1(data):
    plt.figure(figsize=(10, 6))
    sns.countplot(x='size', data=data, order=sorted(data['size'].unique()))
    plt.xlabel('Clothing Size')
    plt.ylabel('Count')
    plt.title('Distribution of Clothing Size')
    
    # Calculate left 95% of the data
    upper_bound = np.percentile(data['size'], 98)
    plt.axvline(x=upper_bound, color='red', linestyle='--', label='95th Percentile')
    
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.legend()
    plt.tight_layout()
    plt.show()
    
def plot_size_distribution2(data):
    plt.figure(figsize=(10, 6))
    sns.countplot(x='size', data=data, order=sorted(data['size'].unique()))
    plt.xlabel('Clothing Size')
    plt.ylabel('Count')
    plt.title('Distribution of Clothing Size')
    
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.legend()
    plt.tight_layout()
    plt.show()
    
plot_size_distribution1(df1)
plot_size_distribution2(rent_data)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# drop nan on body type

# %%
rent_data= df1.dropna(subset=['body type'])

# %% [markdown]
# balanced the data

# %%
fit_counts = rent_data['fit'].value_counts()
fit_counts
# Out:
# fit
# fit      128856
# small     23182
# large     22606
# Name: count, dtype: int64

# %%
target_size_large = fit_counts['large']


small_data_adjusted = rent_data[rent_data['fit'] == 'small'].sample(n=target_size_large, random_state=42, replace=False)
fit_data_adjusted = rent_data[rent_data['fit'] == 'fit'].sample(n=target_size_large, random_state=42, replace=False)
large_data_adjusted = rent_data[rent_data['fit'] == 'large']


balanced_data_adjusted = pd.concat([small_data_adjusted, fit_data_adjusted, large_data_adjusted])


balanced_data_adjusted = balanced_data_adjusted.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df = balanced_data_adjusted.drop(
    columns=['bust size', 'weight', 'rented for', 'review_text', 'category', 'height', 'age', 'review_date']
)

# %%
df.dropna(subset=['body type'])
# Out:
#          fit  user_id  item_id  rating          body type  \
# 0      large   773847  2587651    10.0           athletic
# 1        fit    96369   597613    10.0  straight & narrow
# 2      large   658008  2487984    10.0          hourglass
# 3      large   822017  2150654     6.0          hourglass
# 4        fit   291190   178527    10.0           athletic
# ...      ...      ...      ...     ...                ...
# 67813    fit   306218  2679540    10.0           athletic
# 67814  small   129868   124204     8.0               pear
# 67815  large   352647   143094    10.0           athletic
# 67816  small   818223   877767    10.0           athletic
# 67817  small   421436  1567312     8.0           athletic
#
#                                           review_summary  size  height_cm  \
# 0      Beautiful cut, color and lines! Elegant fabric...     1     154.94
# 1                           Want to wear this every day!     4     162.56
# 2      So cozy for a rainy foggy day. My husband thin...    14     170.18
# 3                                          kept me warm!     8     170.18
# 4                                   Sad to send it back!     4     157.48
# ...                                                  ...   ...        ...
# 67813                                       Fun and Cute     8     175.26
# 67814  I wore this for the my 30th birthday, a great ...    20     172.72
# 67815                                    Very fun dress!     4     162.56
# 67816                                  Black Tie Beauty!    17     167.64
# 67817  Sassy bow in the back, large flowy skirt in th...    12     165.10
#
#        weight_kg
# 0       47.62716
# 1       49.89512
# 2       58.96696
# 3       65.77084
# 4       56.69900
# ...          ...
# 67813   63.50288
# 67814   81.64656
# 67815   56.69900
# 67816   68.03880
# 67817   72.57472
#
# [67818 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# body type
# hourglass            21328
# athletic             16719
# pear                  8641
# petite                8399
# full bust             5953
# straight & narrow     5596
# apple                 1961
# Name: count, dtype: int64
