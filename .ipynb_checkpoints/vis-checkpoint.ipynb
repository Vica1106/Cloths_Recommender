# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('./data/renttherunway_balanced_data.csv')

# %%
df
# Out:
#          fit  user_id bust size  item_id  weight  rating rented for  \
# 0        fit   973869       34b   904766  138lbs    10.0    wedding
# 1      large   703862       36b  1366699     NaN     2.0    wedding
# 2      small    96023       32b   640121  125lbs    10.0      party
# 3      small   586056       NaN  1869056     NaN     8.0   everyday
# 4      small   882650       34c  1523096  126lbs    10.0    wedding
# ...      ...      ...       ...      ...     ...     ...        ...
# 74116    fit   227617      36dd  2589683  150lbs     8.0   everyday
# 74117  small   364913       36c  1832871  149lbs     8.0    wedding
# 74118  large   587983   36ddd/e   132738  200lbs    10.0    wedding
# 74119  small    94885       34c  1076484  155lbs     8.0    wedding
# 74120  small    94781       34d   152836  126lbs    10.0      party
#
#                                              review_text          body type  \
# 0      This dress fit true to size. I received compli...  straight & narrow
# 1      Even though I used the sizing chart, I wasn't ...          hourglass
# 2      Great style for maternity. Unique dress which ...          hourglass
# 3      This is a really pretty dress but I didn't rea...          hourglass
# 4      I picked this dress a few months before the we...  straight & narrow
# ...                                                  ...                ...
# 74116  Loved the color. Fabric substantial and hangs ...          hourglass
# 74117  Based on the other reviews I ordered an 8 (thi...           athletic
# 74118  It fit perfect. I have a large bust(38 DDD), s...          hourglass
# 74119  I really liked the look of the dress and got a...           athletic
# 74120  Got this dress totally last minute for this ev...  straight & narrow
#
#                                           review_summary category  height  \
# 0                                      Gorgeous in Green   sheath  5' 10"
# 1                                    Runs a little large   sheath   5' 6"
# 2                Loved this dress! Photographs so well.     dress   5' 5"
# 3                             Looked different in person    dress   5' 9"
# 4                                      Beautiful dress!!    dress   5' 3"
# ...                                                  ...      ...     ...
# 74116                                   Beautiful color       top   5' 8"
# 74117                          Loved the color and shape   sheath   5' 4"
# 74118  I rented this dress for my 2nd dress after our...     gown   5' 4"
# 74119                             Beautiful and special!    dress   5' 5"
# 74120      GREAT Dress....Runs a tad small...VERY short.     mini   5' 6"
#
#        size   age         review_date  height_cm  weight_kg
# 0         8  30.0  September 19, 2016     177.80  62.595696
# 1        45  30.0        May 31, 2014     167.64  62.319780
# 2         8  38.0     August 29, 2017     165.10  56.699000
# 3        12  37.0      August 9, 2016     175.26  62.319780
# 4        16  36.0      March 20, 2017     160.02  57.152592
# ...     ...   ...                 ...        ...        ...
# 74116    20  36.0    October 26, 2017     172.72  68.038800
# 74117    16  27.0     January 6, 2015     162.56  67.585208
# 74118    16  35.0      April 11, 2013     162.56  90.718400
# 74119    20  31.0    October 12, 2014     165.10  70.306760
# 74120     1  32.0     August 23, 2013     167.64  57.152592
#
# [74121 rows x 17 columns]

# %%
def plot_height_weight_distributions(data):
    fig, axes = plt.subplots(1, 2, figsize=(16, 5))
    
    # Height Distribution
    sns.histplot(data['height_cm'], kde=True, bins=30, ax=axes[0], color='teal')
    axes[0].set_xlabel('Height (cm)')
    axes[0].set_ylabel('Frequency')
    axes[0].set_title('Distribution of Height')
    
    # Weight Distribution
    sns.histplot(data['weight_kg'], kde=True, bins=30, ax=axes[1], color='coral')
    axes[1].set_xlabel('Weight (kg)')
    axes[1].set_ylabel('Frequency')
    axes[1].set_title('Distribution of Weight')
    
    plt.savefig('Distribution of Height & Weight.png')
    plt.tight_layout()
    plt.show()
    
plot_height_weight_distributions(df)

# %%
def plot_size_distribution(data):
    plt.figure(figsize=(10, 6))
    sns.countplot(x='size', data=data, order=sorted(data['size'].unique()))
    plt.xlabel('Clothing Size')
    plt.ylabel('Count')
    plt.title('Distribution of Clothing Size')
    
    # Calculate central 95% of the data
    lower_bound = np.percentile(data['size'], 2.5)
    upper_bound = np.percentile(data['size'], 97.5)
    
    # Draw red lines for central 95%
    plt.axvline(x=lower_bound, color='red', linestyle='--', label='2.5th Percentile')
    plt.axvline(x=upper_bound, color='red', linestyle='--', label='97.5th Percentile')
    
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.legend()
    plt.tight_layout()
    plt.show()
    
plot_size_distribution(df)

# %%
# Height vs. Weight by Fit
def plot_height_vs_weight_by_fit(data):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='height_cm', y='weight_kg', hue='fit', data=data)
    plt.xlabel('Height (cm)')
    plt.ylabel('Weight (kg)')
    plt.title('Height vs. Weight by Fit')
    plt.legend(title='Fit')
    plt.savefig('height_vs_weight_by_fit.png')
    plt.show()

plot_height_vs_weight_by_fit(df)

# %%
# Body Type Distribution
def plot_body_type_distribution(data):
    plt.figure(figsize=(10, 6))
    sns.countplot(y='body type', data=data, order=data['body type'].value_counts().index)
    plt.xlabel('Count')
    plt.ylabel('Body Type')
    plt.title('Distribution of Body Types')
    plt.savefig('body_type.png')
    plt.show()
plot_body_type_distribution(df)

# %%
# Body Type Distribution
def plot_body_type_distribution(data):
    plt.figure(figsize=(10, 6))
    sns.countplot(y='body type', data=data, order=data['body type'].value_counts().index)
    plt.xlabel('Count')
    plt.ylabel('Body Type')
    plt.title('Distribution of Body Types')
    plt.savefig('body_type.png')
    plt.show()

# Fit Distribution
def plot_fit_distribution(data):
    plt.figure(figsize=(8, 5))
    sns.countplot(x='fit', data=data)
    plt.xlabel('Fit (Small, Fit, Large)')
    plt.ylabel('Count')
    plt.title('Fit Distribution')
    plt.savefig('distribution_fit.png')
    plt.show()


plot_body_type_distribution(df)
plot_fit_distribution(df)

# %%
rent_data_cleaned["fit"].value_counts()
# Out:
# fit
# fit      136481
# small     24580
# large     23768
# Name: count, dtype: int64
